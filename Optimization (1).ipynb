# %%
# !pip install gurobipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gurobipy
#   Downloading gurobipy-9.5.2-cp37-cp37m-manylinux2014_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 1.9 MB/s
# Installing collected packages: gurobipy
# Successfully installed gurobipy-9.5.2

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
import random

# %%
orders = pd.read_csv('orders.csv')
couriers = pd.read_csv('partners_delays.csv')

# %%
orders['date'] = pd.to_datetime(orders['date'])
couriers['dttm'] = pd.to_datetime(couriers['dttm'])

# %% [markdown]
# ### Что тут происходит? Мы ожидаем получить датасет с датой, зонами доставки, количеством курьеров и количеством заказов. На выходе мы получаем датасет, в котором столбцы имеют вид data_area, где data это день без часов(2021-04-01), а area это зона доставки. Еще у нас есть столбец time, в котором находятся числа от 8 до 23, это часы доставки, там будет написано, сколько курьеров нам нужно.

# %%
def optimize(dataset):
  index = 0
  work_shifts = [3, 4, 5, 6, 7]
  dict_list = []
  
  for area in dataset['delivery_area_id'].unique():
    for i in range(7):
      start_date = dataset['dttm'].loc[index]
      end_date = (dataset[(dataset['delivery_area_id'] == area) & (dataset['dttm'] < start_date + pd.DateOffset(days=1))]['dttm'].index)[-1]
      ord_count = dataset['orders'][index:end_date + 1].sum()
      dates = {}
      for i in range(index, end_date+1):
        dates[str(new.loc[i]['dttm'])] = new.loc[i]['orders']

      max_workers = int(new['partners_cnt'][index:end_date+1].max())

      worker = {}
      for i in range(max_workers):
        worker['{}'.format(i)] = 1
      workers, pay = gp.multidict(worker)

      c = 0
      availability = gp.tuplelist([])
      for i in range(index, end_date+1):
        for k in range(int(new.loc[i]['partners_cnt'])):
          if c == max_workers:
            c = 0
          availability.append(('{}'.format(workers[c]),'{}'.format(new.loc[i]['dttm'])))
          c+= 1

      index = end_date + 1
      shifts, shiftRequirements = gp.multidict(dates)

      m = gp.Model("workforce5")
      x = m.addVars(availability, vtype=GRB.BINARY, name="x")
      slacks = m.addVars(shifts, name="Slack")
      totSlack = m.addVar(name='totSlack')
      totShifts = m.addVars(workers, name="TotShifts")
      shift_reqmts = m.addConstrs((x.sum('*',s) + slacks[s] == shiftRequirements[s] for s in shifts), name='shiftRequirement')
      num_temps = m.addConstr(totSlack == slacks.sum(), name='totSlack')
      num_shifts = m.addConstrs((totShifts[w] == x.sum(w,'*') for w in workers), name='totShifts')
      minShift = m.addVar(4, name='minShift')
      maxShift = m.addVar(8,name='maxShift')
      min_constr = m.addGenConstrMin(minShift, totShifts, name='minShift')
      """ Если убрать комментари со следующей строки кода, то мы получим ограничение на макс. продолжительность смены 8 часов,
          Но существуют такие дни, когда это условие не может выполниться, курьеров значительно меньше, чем заказов, и либо кто-то
          Не получает свой заказ, либо кто-то работает больше 8 часов(Я так это понял)
      """ 
      #max_constr = m.addGenConstrMin(maxShift, totShifts, name='maxShift')
      m.ModelSense = GRB.MINIMIZE
      m.setObjectiveN(totSlack, index=0, priority=2, reltol=0.2, name='TotalSlack')
      m.setObjectiveN(maxShift - minShift, index=1, priority=1, name='Fairness')
      m.write('workforce.lp')
      m.optimize()
      # The Status attribute  provides current optimization status of the model object m
      # In workforce model, we check if the model is infeasible or unbounded and report this situation
      status = m.Status
      if status == GRB.Status.INF_OR_UNBD or status == GRB.Status.INFEASIBLE  or status == GRB.Status.UNBOUNDED:
          print('The model cannot be solved because it is infeasible or unbounded')
          sys.exit(0)
      # If the optimization status of the model is not optimal for some other reason, we report that 
      # situation.
      if status != GRB.Status.OPTIMAL:
          print('Optimization was stopped with status ' + str(status))
          sys.exit(0)

      # Print total slack and the number of shifts worked for each worker
      # The KPIs for this optimization number is the number of extra worked required to satisfy 
      # demand and the number of shifts that each employed worker is working.
      solution = {}
      shifts_sol = {}
      solution['Total slack required'] = str(totSlack.X)
      assignments_all = {}
      gant={}

      assignments = dict()
      for [w, s] in availability:
          if x[w, s].x == 1:
              if w in assignments:
                  assignments[w].append(s)
              else:
                  assignments[w] = [s]

      """
      Уберите комментарии если хотите увидеть графики распределения смен
      """
      #print(pd.DataFrame.from_records(list(solution.items()), columns=['KPI', 'Value']))
      #print('-'*50)

      for w in workers:
          shifts_sol[w]=totShifts[w].X
          assignments_all[w]=assignments.get(w, [])

      #print('Shifts')
      #print(pd.DataFrame.from_records(list(shifts_sol.items()), columns=['Worker', 'Number of shifts']))
          
      y_pos = np.arange(len(shifts_sol.keys())) 
      #plt.bar(y_pos,shifts_sol.values() , align='center')
      #plt.xticks(y_pos, shifts_sol.keys())
      #plt.show()

      #print('-'*50)
      for w in assignments_all:
          gant[w] = [w]
          for d in shifts:
              gant[w].append('*' if d in assignments_all[w] else '-')

      #print('Assigments')
      #print('Symbols: \'-\': not working, \'*\': working')
      #pd.set_option('display.width', 1000)
      #print(pd.DataFrame.from_records(list(gant.values()), columns=['worker']+shifts))
      #print(pd.DataFrame.from_records(list(gant.values())))
      df['{}'.format(str(start_date)[:10])+"_"+str(area)] = 0
      for i in range(len(shifts)):
        cour = 0
        for k in workers:
          if gant[k][i +1 ] == '*':
            cour += 1

        ind = df[(df['time'] == pd.to_datetime(shifts[i]).hour)].index
        df['{}'.format(str(shifts[i])[:10])+"_"+str(area)][ind] = cour
  return df

# %%
optimize(new)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 12 rows and 11 columns
# Presolve time: 0.00s
# Presolved: 4 rows and 21 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Presolve added 1 rows and 0 columns
# Presolve removed 0 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 9 columns, 15 nonzeros
# Variable types: 3 continuous, 6 integer (4 binary)
# Found heuristic solution: objective 55.0000000
# Found heuristic solution: objective 54.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: 54 55
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.400000000000e+01, best bound 5.400000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 2
#
#
# Explored 0 nodes (0 simplex iterations) in 0.21 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.23 seconds (0.00 work units), solution count 2
#
# Warning: variable name "x[0,2021-04-07 09:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-07 09:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 17 rows, 37 columns and 66 nonzeros
# Model fingerprint: 0x253b0679
# Model has 1 general constraint
# Variable types: 19 continuous, 18 integer (18 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 6 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 11 rows and 30 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 72.0000000
# Presolve removed 3 rows and 18 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 12 columns, 22 nonzeros
# Found heuristic solution: objective 68.0000000
# Variable types: 4 continuous, 8 integer (5 binary)
#
# Root relaxation: objective 6.700000e+01, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      67.0000000   67.00000  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 67 68 72
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.700000000000e+01, best bound 6.700000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 3
#
#
# Explored 0 nodes (0 simplex iterations) in 0.12 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+00, best bound 3.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.14 seconds (0.00 work units), solution count 3
#
# Warning: variable name "x[0,2021-04-01 07:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-01 07:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 19 rows, 38 columns and 69 nonzeros
# Model fingerprint: 0xf17ba8bc
# Model has 1 general constraint
# Variable types: 21 continuous, 17 integer (17 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 13 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 6 rows and 24 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 77.0000000
# Presolve removed 2 rows and 18 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 6 columns, 10 nonzeros
# Found heuristic solution: objective 69.0000000
# Variable types: 3 continuous, 3 integer (1 binary)
#
# Root relaxation: objective 6.800000e+01, 0 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      68.0000000   68.00000  0.00%     -    0s
#
# Explored 1 nodes (0 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 68 69 77
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.800000000000e+01, best bound 6.800000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 0
#
#
# Explored 0 nodes (0 simplex iterations) in 0.12 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.14 seconds (0.00 work units), solution count 3
#
# Warning: variable name "x[0,2021-04-02 07:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-02 07:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 18 rows, 36 columns and 66 nonzeros
# Model fingerprint: 0x46386a08
# Model has 1 general constraint
# Variable types: 20 continuous, 16 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 17 rows and 18 columns
# Presolve time: 0.00s
# Presolved: 1 rows and 18 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 95.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 95
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.500000000000e+01, best bound 9.500000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective -8
#
#
# Explored 0 nodes (0 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: -8
# No other solutions better than -8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -8.000000000000e+00, best bound -8.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.11 seconds (0.00 work units), solution count 1
#
# Warning: variable name "x[0,2021-04-03 07:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-03 07:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 19 rows, 38 columns and 69 nonzeros
# Model fingerprint: 0xfe869994
# Model has 1 general constraint
# Variable types: 21 continuous, 17 integer (17 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 13 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 6 rows and 24 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 93.0000000
# Presolve removed 2 rows and 18 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 6 columns, 10 nonzeros
# Found heuristic solution: objective 85.0000000
# Variable types: 3 continuous, 3 integer (1 binary)
#
# Root relaxation: objective 8.400000e+01, 0 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      84.0000000   84.00000  0.00%     -    0s
#
# Explored 1 nodes (0 simplex iterations) in 0.14 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 84 85 93
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.400000000000e+01, best bound 8.400000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 0
#
#
# Explored 0 nodes (0 simplex iterations) in 0.18 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.20 seconds (0.00 work units), solution count 3
#
# Warning: variable name "x[0,2021-04-04 07:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-04 07:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 19 rows, 38 columns and 69 nonzeros
# Model fingerprint: 0x529688dc
# Model has 1 general constraint
# Variable types: 21 continuous, 17 integer (17 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [3e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 13 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 6 rows and 24 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 91.0000000
# Presolve removed 2 rows and 18 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 6 columns, 10 nonzeros
# Found heuristic solution: objective 83.0000000
# Variable types: 3 continuous, 3 integer (1 binary)
#
# Root relaxation: objective 8.200000e+01, 0 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      82.0000000   82.00000  0.00%     -    0s
#
# Explored 1 nodes (0 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 82 83 91
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.200000000000e+01, best bound 8.200000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 0
#
#
# Explored 0 nodes (0 simplex iterations) in 0.13 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.15 seconds (0.00 work units), solution count 3
#
# Warning: variable name "x[0,2021-04-05 07:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-05 07:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 20 rows, 45 columns and 82 nonzeros
# Model fingerprint: 0xa82f2b4f
# Model has 1 general constraint
# Variable types: 22 continuous, 23 integer (23 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 8e+00]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 9 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 11 rows and 35 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 71.0000000
# Presolve removed 3 rows and 23 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 12 columns, 22 nonzeros
# Found heuristic solution: objective 63.0000000
# Variable types: 4 continuous, 8 integer (5 binary)
#
# Root relaxation: objective 6.100000e+01, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   61.00000    0    3   63.00000   61.00000  3.17%     -    0s
# H    0     0                      62.0000000   61.00000  1.61%     -    0s
# H    0     0                      61.0000000   61.00000  0.00%     -    0s
#      0     0   61.00000    0    3   61.00000   61.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 61 62 63 71
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.100000000000e+01, best bound 6.100000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 1
#
#
# Explored 0 nodes (0 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.09 seconds (0.00 work units), solution count 4
#
# Warning: variable name "x[0,2021-04-06 07:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-06 07:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 20 rows, 44 columns and 80 nonzeros
# Model fingerprint: 0x7125ab6a
# Model has 1 general constraint
# Variable types: 22 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 9e+00]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 8 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 12 rows and 35 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 52.0000000
# Presolve removed 3 rows and 21 columns
# Presolve time: 0.00s
# Presolved: 9 rows, 14 columns, 26 nonzeros
# Found heuristic solution: objective 45.0000000
# Variable types: 4 continuous, 10 integer (7 binary)
#
# Root relaxation: objective 4.400000e+01, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   44.00000    0    2   45.00000   44.00000  2.22%     -    0s
# H    0     0                      44.0000000   44.00000  0.00%     -    0s
#      0     0   44.00000    0    2   44.00000   44.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 44 45 52
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.400000000000e+01, best bound 4.400000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 2
#
#
# Explored 0 nodes (0 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.23 seconds (0.00 work units), solution count 3
#
# Warning: variable name "x[0,2021-04-07 07:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-07 07:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 18 rows, 36 columns and 66 nonzeros
# Model fingerprint: 0xe07a2b3c
# Model has 1 general constraint
# Variable types: 20 continuous, 16 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 17 rows and 18 columns
# Presolve time: 0.00s
# Presolved: 1 rows and 18 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 49.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 49
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.900000000000e+01, best bound 4.900000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective -8
#
#
# Explored 0 nodes (0 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: -8
# No other solutions better than -8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -8.000000000000e+00, best bound -8.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.06 seconds (0.00 work units), solution count 1
#
# Warning: variable name "x[0,2021-04-01 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-01 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 17 rows, 37 columns and 67 nonzeros
# Model fingerprint: 0xef02f736
# Model has 1 general constraint
# Variable types: 19 continuous, 18 integer (18 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 10 rows and 11 columns
# Presolve time: 0.00s
# Presolved: 7 rows and 26 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 60.0000000
# Presolve removed 2 rows and 17 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 9 columns, 15 nonzeros
# Found heuristic solution: objective 52.0000000
# Variable types: 3 continuous, 6 integer (4 binary)
#
# Root relaxation: objective 5.100000e+01, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      51.0000000   51.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 51 52 60
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.100000000000e+01, best bound 5.100000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 0
#
#
# Explored 0 nodes (0 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.08 seconds (0.00 work units), solution count 3
#
# Warning: variable name "x[0,2021-04-02 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-02 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 18 rows, 41 columns and 74 nonzeros
# Model fingerprint: 0x14b78fb1
# Model has 1 general constraint
# Variable types: 20 continuous, 21 integer (21 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 8 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 10 rows and 32 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 57.0000000
# Presolve removed 3 rows and 22 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 10 columns, 18 nonzeros
# Found heuristic solution: objective 48.0000000
# Variable types: 4 continuous, 6 integer (3 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: 48 57
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.800000000000e+01, best bound 4.800000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 1
#
#
# Explored 0 nodes (0 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.07 seconds (0.00 work units), solution count 2
#
# Warning: variable name "x[0,2021-04-03 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-03 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 16 rows, 32 columns and 58 nonzeros
# Model fingerprint: 0x588bcd09
# Model has 1 general constraint
# Variable types: 18 continuous, 14 integer (14 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 15 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 1 rows and 16 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 67.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.700000000000e+01, best bound 6.700000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective -6
#
#
# Explored 0 nodes (0 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: -6
# No other solutions better than -6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -6.000000000000e+00, best bound -6.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.16 seconds (0.00 work units), solution count 1
#
# Warning: variable name "x[0,2021-04-04 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-04 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 17 rows, 35 columns and 63 nonzeros
# Model fingerprint: 0x31e9e86b
# Model has 1 general constraint
# Variable types: 19 continuous, 16 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 10 rows and 11 columns
# Presolve time: 0.00s
# Presolved: 7 rows and 24 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 88.0000000
# Presolve removed 2 rows and 15 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 9 columns, 15 nonzeros
# Found heuristic solution: objective 82.0000000
# Variable types: 3 continuous, 6 integer (4 binary)
#
# Root relaxation: objective 8.100000e+01, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      81.0000000   81.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 81 82 88
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.100000000000e+01, best bound 8.100000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 1
#
#
# Explored 0 nodes (0 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.08 seconds (0.00 work units), solution count 3
#
# Warning: variable name "x[0,2021-04-05 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-05 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 18 rows, 40 columns and 72 nonzeros
# Model fingerprint: 0xbe717682
# Model has 1 general constraint
# Variable types: 20 continuous, 20 integer (20 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [2e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 8 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 10 rows and 31 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 73.0000000
# Presolve removed 3 rows and 21 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 10 columns, 18 nonzeros
# Found heuristic solution: objective 65.0000000
# Variable types: 4 continuous, 6 integer (3 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: 65 73
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 2
#
#
# Explored 0 nodes (0 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.08 seconds (0.00 work units), solution count 2
#
# Warning: variable name "x[0,2021-04-06 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-06 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 17 rows, 38 columns and 69 nonzeros
# Model fingerprint: 0xd7b0951c
# Model has 1 general constraint
# Variable types: 19 continuous, 19 integer (19 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 10 rows and 11 columns
# Presolve time: 0.00s
# Presolved: 7 rows and 27 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 87.0000000
# Presolve removed 2 rows and 18 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 9 columns, 15 nonzeros
# Found heuristic solution: objective 78.0000000
# Variable types: 3 continuous, 6 integer (4 binary)
#
# Root relaxation: objective 7.700000e+01, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      77.0000000   77.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 77 78 87
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.700000000000e+01, best bound 7.700000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective -1
#
#
# Explored 0 nodes (0 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: -1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.000000000000e+00, best bound -1.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.08 seconds (0.00 work units), solution count 3
#
# Warning: variable name "x[0,2021-04-07 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-07 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 18 rows, 43 columns and 78 nonzeros
# Model fingerprint: 0x098686ac
# Model has 1 general constraint
# Variable types: 20 continuous, 23 integer (23 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 7 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 11 rows and 35 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 76.0000000
# Presolve removed 3 rows and 22 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 13 columns, 24 nonzeros
# Found heuristic solution: objective 67.0000000
# Variable types: 4 continuous, 9 integer (6 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.15 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: 67 76
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.700000000000e+01, best bound 6.700000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 2
#
# Presolve removed 4 rows and 22 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 13 columns, 24 nonzeros
# Variable types: 4 continuous, 9 integer (6 binary)
#
# Root relaxation: objective 1.000000e+00, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.0000000    1.00000  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.18 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: 1 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.19 seconds (0.00 work units), solution count 3
#
# Warning: variable name "x[0,2021-04-01 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-01 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 18 rows, 42 columns and 76 nonzeros
# Model fingerprint: 0x19de7ae7
# Model has 1 general constraint
# Variable types: 20 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 8 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 10 rows and 33 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 77.0000000
# Presolve removed 3 rows and 23 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 10 columns, 18 nonzeros
# Found heuristic solution: objective 67.0000000
# Variable types: 4 continuous, 6 integer (3 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: 67 77
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.700000000000e+01, best bound 6.700000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 1
#
#
# Explored 0 nodes (0 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.08 seconds (0.00 work units), solution count 2
#
# Warning: variable name "x[0,2021-04-02 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-02 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 17 rows, 39 columns and 71 nonzeros
# Model fingerprint: 0x63c538a2
# Model has 1 general constraint
# Variable types: 19 continuous, 20 integer (20 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 11 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 6 rows and 27 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 59.0000000
# Presolve removed 2 rows and 21 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 6 columns, 10 nonzeros
# Found heuristic solution: objective 47.0000000
# Variable types: 3 continuous, 3 integer (1 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: 47 59
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.700000000000e+01, best bound 4.700000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective -2
#
#
# Explored 0 nodes (0 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: -2
# No other solutions better than -2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.000000000000e+00, best bound -2.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.13 seconds (0.00 work units), solution count 2
#
# Warning: variable name "x[0,2021-04-03 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-03 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 18 rows, 39 columns and 70 nonzeros
# Model fingerprint: 0x146b70f6
# Model has 1 general constraint
# Variable types: 20 continuous, 19 integer (19 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
# ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 0
#
#
# Explored 0 nodes (0 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.07 seconds (0.00 work units), solution count 2
#
# Warning: variable name "x[0,2021-04-04 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-04 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 17 rows, 36 columns and 65 nonzeros
# Model fingerprint: 0xb86b689c
# Model has 1 general constraint
# Variable types: 19 continuous, 17 integer (17 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 10 rows and 11 columns
# Presolve time: 0.00s
# Presolved: 7 rows and 25 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 64.0000000
# Presolve removed 2 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 9 columns, 15 nonzeros
# Found heuristic solution: objective 57.0000000
# Variable types: 3 continuous, 6 integer (4 binary)
#
# Root relaxation: objective 5.600000e+01, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      56.0000000   56.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 56 57 64
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.600000000000e+01, best bound 5.600000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 0
#
#
# Explored 0 nodes (0 simplex iterations) in 0.12 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.15 seconds (0.00 work units), solution count 3
#
# Warning: variable name "x[0,2021-04-05 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-05 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 17 rows, 35 columns and 63 nonzeros
# Model fingerprint: 0x52fab3fe
# Model has 1 general constraint
# Variable types: 19 continuous, 16 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [2e+00, 9e+00]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 11 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 6 rows and 23 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 72.0000000
# Presolve removed 2 rows and 17 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 6 columns, 10 nonzeros
# Found heuristic solution: objective 64.0000000
# Variable types: 3 continuous, 3 integer (1 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: 64 72
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.400000000000e+01, best bound 6.400000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 0
#
#
# Explored 0 nodes (0 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.12 seconds (0.00 work units), solution count 2
#
# Warning: variable name "x[0,2021-04-06 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-06 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 17 rows, 37 columns and 67 nonzeros
# Model fingerprint: 0xa69ee691
# Model has 1 general constraint
# Variable types: 19 continuous, 18 integer (18 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 11 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 6 rows and 25 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 61.0000000
# Presolve removed 2 rows and 19 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 6 columns, 10 nonzeros
# Found heuristic solution: objective 51.0000000
# Variable types: 3 continuous, 3 integer (1 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.13 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: 51 61
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.100000000000e+01, best bound 5.100000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective -1
#
#
# Explored 0 nodes (0 simplex iterations) in 0.16 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: -1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.000000000000e+00, best bound -1.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.18 seconds (0.00 work units), solution count 2
#
# Warning: variable name "x[0,2021-04-07 08:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-07 08:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 18 rows, 42 columns and 76 nonzeros
# Model fingerprint: 0x2d52c54d
# Model has 1 general constraint
# Variable types: 20 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [2e+00, 1e+01]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 8 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 10 rows and 33 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 75.0000000
# Presolve removed 3 rows and 23 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 10 columns, 18 nonzeros
# Found heuristic solution: objective 65.0000000
# Variable types: 4 continuous, 6 integer (3 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: 65 75
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 1
#
#
# Explored 0 nodes (0 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.12 seconds (0.00 work units), solution count 2
#
# Warning: variable name "x[0,2021-04-01 09:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-01 09:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 15 rows, 30 columns and 54 nonzeros
# Model fingerprint: 0x46cd37b9
# Model has 1 general constraint
# Variable types: 17 continuous, 13 integer (13 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 9e+00]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 14 rows and 15 columns
# Presolve time: 0.00s
# Presolved: 1 rows and 15 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 69.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 69
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.900000000000e+01, best bound 6.900000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective -5
#
#
# Explored 0 nodes (0 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: -5
# No other solutions better than -5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.000000000000e+00, best bound -5.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.13 seconds (0.00 work units), solution count 1
#
# Warning: variable name "x[0,2021-04-02 09:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-02 09:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 15 rows, 30 columns and 54 nonzeros
# Model fingerprint: 0x9397facb
# Model has 1 general constraint
# Variable types: 17 continuous, 13 integer (13 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [2e+00, 9e+00]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 14 rows and 15 columns
# Presolve time: 0.00s
# Presolved: 1 rows and 15 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 (TotalSlack) ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 54.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 54
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.400000000000e+01, best bound 5.400000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 (Fairness) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective -5
#
#
# Explored 0 nodes (0 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: -5
# No other solutions better than -5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.000000000000e+00, best bound -5.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.12 seconds (0.00 work units), solution count 1
#
# Warning: variable name "x[0,2021-04-03 09:00:00]" has a space
# Warning: constraint name "shiftRequirement[2021-04-03 09:00:00]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
